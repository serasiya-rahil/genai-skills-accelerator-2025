# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv('weather_data.csv')

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.rename(columns={
    'Date/Time': 'Datetime',
    'Temp_C': 'Temperature',
    'Dew Point Temp_C': 'DewPointTemp',
    'Rel Hum_%': 'Humidity',
    'Wind Speed_km/h': 'WindSpeed',
    'Visibility_km': 'Visibility',
    'Press_kPa': 'Pressure',
    'Weather': 'WeatherCondition'
}, inplace=True)

# %%
df.head()
# Out:
#         Datetime  Temperature  DewPointTemp  Humidity  WindSpeed  Visibility  \
# 0  1/1/2012 0:00         -1.8          -3.9        86          4         8.0
# 1  1/1/2012 1:00         -1.8          -3.7        87          4         8.0
# 2  1/1/2012 2:00         -1.8          -3.4        89          7         4.0
# 3  1/1/2012 3:00         -1.5          -3.2        88          6         4.0
# 4  1/1/2012 4:00         -1.5          -3.3        88          7         4.8
#
#    Pressure      WeatherCondition
# 0    101.24                   Fog
# 1    101.24                   Fog
# 2    101.26  Freezing Drizzle,Fog
# 3    101.27  Freezing Drizzle,Fog
# 4    101.23                   Fog

# %%
#check for null values
df.isnull().sum()
# Out:
# Datetime            0
# Temperature         0
# DewPointTemp        0
# Humidity            0
# WindSpeed           0
# Visibility          0
# Pressure            0
# WeatherCondition    0
# dtype: int64

# %%
label_encoder = LabelEncoder()
df['WeatherCondition_encoded'] = label_encoder.fit_transform(df['WeatherCondition'])

# %%
df.head()
# Out:
#         Datetime  Temperature  DewPointTemp  Humidity  WindSpeed  Visibility  \
# 0  1/1/2012 0:00         -1.8          -3.9        86          4         8.0
# 1  1/1/2012 1:00         -1.8          -3.7        87          4         8.0
# 2  1/1/2012 2:00         -1.8          -3.4        89          7         4.0
# 3  1/1/2012 3:00         -1.5          -3.2        88          6         4.0
# 4  1/1/2012 4:00         -1.5          -3.3        88          7         4.8
#
#    Pressure      WeatherCondition  WeatherCondition_encoded
# 0    101.24                   Fog                         7
# 1    101.24                   Fog                         7
# 2    101.26  Freezing Drizzle,Fog                         9
# 3    101.27  Freezing Drizzle,Fog                         9
# 4    101.23                   Fog                         7

# %%
features = ['Temperature','DewPointTemp','Humidity','WindSpeed','Visibility','Pressure']
target = 'WeatherCondition_encoded'
